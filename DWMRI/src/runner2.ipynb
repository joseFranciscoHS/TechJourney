# %%
import torch
torch.__version__
# Out:
# '2.6.0+cu124'

# %%
# from drcnet_hybrid_multiple_networks.run import main
# from drcnet_hybrid.run import main
from restormer_hybrid.run import main
# from mds2s.run import main

# %%
main("dbrain")

# metrics

## mds2s
### 0.1 {'psnr': 20.75483775311783, 'ssim': 0.3659183382987976, 'mse': 0.008404584049680605}

## drcnet
### 0.1 {'psnr': 21.002585178163354, 'ssim': 0.3720719814300537, 'mse': 0.00793855544179678}

## drcnet sinusoidal encoding with CBAM and mean input -- lr 0.001
### {'psnr': 19.70985296358925, 'ssim': 0.3897143304347992, 'mse': 0.010690910741686821}

# Reconstructed DWIs min: 0.0461, max: 1.0992, mean: 0.2084
# Original DWIs min: 0.0000, max: 1.0000, mean: 0.1140
# Out:
# 2026-03-05 17:33:04,059 - root - INFO - Logging configured - level: INFO, file: logs/training_20260305_173304.log
# 2026-03-05 17:33:04,061 - root - INFO - Starting Restormer3D training with dataset: dbrain
# 2026-03-05 17:33:04,062 - root - INFO - Loading config from: /home/paco/TechJourney/TechJourney/DWMRI/src/restormer_hybrid/config.yaml
# 2026-03-05 17:33:04,063 - root - INFO - Loading configuration from: /home/paco/TechJourney/TechJourney/DWMRI/src/restormer_hybrid/config.yaml
# 2026-03-05 17:33:04,094 - root - INFO - Configuration file loaded successfully
# 2026-03-05 17:33:04,097 - root - INFO - Configuration converted to Munch object
# 2026-03-05 17:33:04,098 - root - INFO - Configuration loaded successfully
# 2026-03-05 17:33:04,099 - root - INFO - Using DBrain dataset configuration
# 2026-03-05 17:33:04,100 - root - INFO - DBrainDataLoader initialized - nii_path: /home/paco/d_brain/D_BRAIN_b2500_6_60_14_HCP_nless.nii, bvecs_path: /home/paco/d_brain/D_BRAIN_b2500_6_60_HCP_b_matrix.txt, bvalue: 2500, noise_sigma: 0.1
# 2026-03-05 17:33:04,101 - root - INFO - DBrainDataLoader initialized with noise_sigma=0.1
# 2026-03-05 17:33:04,103 - root - INFO - Setting up wandb...
# 2026-03-05 17:33:04,183 - wandb.jupyter - ERROR - Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: jose-sepulveda (jose-sepulveda-cimat). Use `wandb login --relogin` to force relogin
# wandb version 0.25.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.7
# Run data is saved locally in <code>/home/paco/TechJourney/TechJourney/DWMRI/src/wandb/run-20260305_173305-mu28wlo2</code>
# Syncing run <strong><a href='https://wandb.ai/jose-sepulveda-cimat/DWMRI-Denoising/runs/mu28wlo2' target="_blank">clear-butterfly-137</a></strong> to <a href='https://wandb.ai/jose-sepulveda-cimat/DWMRI-Denoising' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/jose-sepulveda-cimat/DWMRI-Denoising' target="_blank">https://wandb.ai/jose-sepulveda-cimat/DWMRI-Denoising</a>
#  View run at <a href='https://wandb.ai/jose-sepulveda-cimat/DWMRI-Denoising/runs/mu28wlo2' target="_blank">https://wandb.ai/jose-sepulveda-cimat/DWMRI-Denoising/runs/mu28wlo2</a>
# 2026-03-05 17:33:07,595 - root - INFO - Loading data...
# 2026-03-05 17:33:07,596 - root - INFO - Loading data from /home/paco/d_brain/D_BRAIN_b2500_6_60_14_HCP_nless.nii
# pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# 2026-03-05 17:33:07,601 - nibabel.global - INFO - pixdim[0] (qfac) should be 1 (default) or -1; setting qfac to 1
# 2026-03-05 17:33:07,606 - root - INFO - Raw data loaded - shape: (128, 128, 97, 66), dtype: float64
# 2026-03-05 17:33:09,917 - root - INFO - Raw data stats - min: 0.0000, max: 7462.0000, mean: 159.3769
# 2026-03-05 17:33:09,918 - root - INFO - Normalizing spatial dimensions...
# 2026-03-05 17:33:09,920 - root - INFO - Normalizing spatial dimensions for data of shape (128, 128, 97, 66)
# 2026-03-05 17:33:11,572 - root - INFO - Spatial normalization completed - output shape: (128, 128, 97, 66)
# 2026-03-05 17:33:11,742 - root - INFO - Normalized data stats - min: 0.0000, max: 1.0000, mean: 0.1140
# 2026-03-05 17:33:11,744 - root - INFO - Adding Rician noise with sigma=0.1 to normalized data...
# 2026-03-05 17:33:11,745 - root - INFO - Adding Rician noise to normalized data with sigma=0.1 to data of shape (128, 128, 97, 66)
